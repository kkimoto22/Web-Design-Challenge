# %% [markdown]
# ### Convert CSV to HTML

# %%
import pandas as pd
import os

# %%
path = os.path.join("Resources", "cities.csv")

# %%
city_data = pd.read_csv(path)

# %%
city_data
# Out:
#                         City  Cloudiness (%) Country        Date  \
# 0    Saint-André-les-Vergers               0      FR  1621891032
# 1                     Hasaki              22      JP  1621890549
# 2             Saint-Philippe              85      RE  1621890352
# 3                   Khatanga             100      RU  1621891032
# 4                    Mataura               6      NZ  1621890531
# ..                       ...             ...     ...         ...
# 538                Boa Vista              75      BR  1621891158
# 539                  Fortuna               1      US  1621891159
# 540                 Mazatlán               1      MX  1621891159
# 541                   Taltal             100      CL  1621890629
# 542                   Ürümqi               0      CN  1621891159
#
#      Humidity (%)  Latitude  Longitude  Maximum Temperature  Wind Speed (mph)
# 0              76   48.2853     4.0521                48.24             16.11
# ...

# %%
city_data.to_html("data.html")
